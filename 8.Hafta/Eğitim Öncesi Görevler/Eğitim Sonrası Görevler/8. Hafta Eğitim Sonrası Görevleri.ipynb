# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
# 1.Problemin Çözümünü Buraya Yazınız

def vki_hesapla(boy,kilo): 
    vki = kilo / (boy)**2
    print(vki)


def sinif(vki):
    if vki < 18.5:
        return "Zayıf"
    elif 18.5 <= vki < 24.9:
        return "Normal"
    elif 24.9 <= vki < 29.9:
        return "Fazla Kilolu"
    elif 29.9 <= vki < 39.9:
        return "Obez"
    else:
        return "İleri derecede obez (morbid obez)"

def girisler():
    
    giris_sayisi = int(input("Kaç giris yapmak istiyorsunuz?"))
    for i in range(giris_sayisi):
        isim = input("İsim giriniz")
        soyisim = input("Soyisim giriniz")
        yas = int(input("Yas giriniz"))
        boy = float(input("Boy giriniz"))
        kilo = float(input("kilo giriniz"))

    
        vki = vki_hesapla(boy,kilo)

        with open("kilo.txt", "a") as file:
            file.write()




bilgileriniz = f"({isim} {soyisim}, Yasiniz: {yas},\n Kilonuz:{kilo},\n Boyunuz: {boy}\n VKİ:{vki},\n Sınıf: {sinif})"
print(bilgileriniz)



giris_sayisi()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 39
#      33         with open("kilo.txt", "a") as file:
#      34             file.write()
# ---> 39 bilgileriniz = f"({isim} {soyisim}, Yasiniz: {yas},\n Kilonuz:{kilo},\n Boyunuz: {boy}\n VKİ:{vki},\n Sınıf: {sinif})"
#      40 print(bilgileriniz)
#      44 giris_sayisi()
#
# NameError: name 'isim' is not defined

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
# 2.Problemin Çözümünü Buraya Yazınız

import datetime


menu = {
    "strawberry": 20,
    "cholate": 15,
    "banana": 12,
    "milk": 6,
    "mint": 4
}



def see_the_menu():
    for content, price in menu.items():
        print(f"{content.upper()}: {price} TL ")

def get_smoothie():
    sum_price = 0
    picked_content = []
    print("Pick you want from content and when you finish click 'OK'.")

    while True:
        content = input("Content: ")
        if content == 'OK':
            print("Siparişiniz tamamlanıyor...")
            break
        elif content in menu:
            picked_content.append(content)
            sum_price += menu(content)

        if picked_content:
            print(f"Seçilen malzemeler: {','.zip(picked_content)}")
            print(f"Sum price: {sum_price} TL")

            date = datetime.datetime.now().strftime("%d/%M/%Y %H.%M.%S")
            record(date,sum_price)

def record(date,sum_price):
    with open("sales_of_smoothie.txt","w") as file:
        file.write(f"Date: {date}/n Price: {price} TL ")
    print("Sale is recorded.")


def main():
    while True:
        print("\nYetBar - Smoothie Bank")
        print("1. See the menu.")
        print("2. Get your smoothie.")
        

        decision = input("Choose one of them (1/2): ")

        if decision == '1':
            see_the_menu()
        elif decision == '2':
            get_smoothie()
            break
        else:
            print("Please choose one of them '1','2'.")

main()
# Out:
# YetBar - Smoothie Bank
# 1. See the menu.
# 2. Get your smoothie.
# STRAWBERRY: 20 TL
# CHOLATE: 15 TL
# BANANA: 12 TL
# MILK: 6 TL
# MINT: 4 TL
#
# YetBar - Smoothie Bank
# 1. See the menu.
# 2. Get your smoothie.
# STRAWBERRY: 20 TL
# CHOLATE: 15 TL
# BANANA: 12 TL
# MILK: 6 TL
# MINT: 4 TL
#
# YetBar - Smoothie Bank
# 1. See the menu.
# 2. Get your smoothie.
# STRAWBERRY: 20 TL
# CHOLATE: 15 TL
# BANANA: 12 TL
# MILK: 6 TL
# MINT: 4 TL
#
# YetBar - Smoothie Bank
# 1. See the menu.
# 2. Get your smoothie.
# STRAWBERRY: 20 TL
# CHOLATE: 15 TL
# BANANA: 12 TL
# MILK: 6 TL
# MINT: 4 TL
#
# YetBar - Smoothie Bank
# 1. See the menu.
# 2. Get your smoothie.
# Pick you want from content and when you finish click 'OK'.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 64
#      61         else:
#      62             print("Please choose one of them '1','2'.")
# ...
